# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelUTEC26/datawarehouse-seguros/blob/main/Clientes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/MiguelUTEC26/datawarehouse-seguros.git

# %%
import pandas as pd

# %% [markdown]
# BLOQUE 1: CARGA DEL DATASET

# %%
#Ruta del dataset almacenada en GitHub
url = "https://raw.githubusercontent.com/MiguelUTEC26/datawarehouse-seguros/refs/heads/main/data/clientes.csv"

# %%
#Lectura del archivo
df = pd.read_csv(url)
print ("Dataset cargado correctamente")
# Out:
# Dataset cargado correctamente

# %%
display(df.head())
# Out:
#    id_cliente                 nombre                             email  \
# 0           1      José Chávez Pérez      jose.chavez.perez1@gmail.com
# 1           2    Daniela Rojas Ortiz    daniela.rojas.ortiz2@seguro.sv
# 2           3    Ricardo Cruz Flores  ricardo.cruz.flores3@example.com
# 3           4      María Pérez Pérez     maria.perez.perez4@correo.com
# 4           5  Fernanda Chávez Rojas  fernanda.chavez.rojas5@seguro.sv
#
#       genero fecha_nacimiento          ciudad segmento
# 0     Hombre       2011/11/24       SanMiguel      NaN
# 1        NaN         01-02-80        Sta. Ana      NaN
# 2  Masculino         06-18-79       S. Miguel      NaN
# 3  Masculino       1960-09-29      LaLibertad  REGULAR
# 4        NaN       1945/08/02   San Salvador      Pyme

# %% [markdown]
# BLOQUE 2: Exploración del DATASET

# %%
print("Primeras filas del dataset")
display(df.head())
# Out:
# Primeras filas del dataset
#    id_cliente                 nombre                             email  \
# 0           1      José Chávez Pérez      jose.chavez.perez1@gmail.com
# 1           2    Daniela Rojas Ortiz    daniela.rojas.ortiz2@seguro.sv
# 2           3    Ricardo Cruz Flores  ricardo.cruz.flores3@example.com
# 3           4      María Pérez Pérez     maria.perez.perez4@correo.com
# 4           5  Fernanda Chávez Rojas  fernanda.chavez.rojas5@seguro.sv
#
#       genero fecha_nacimiento          ciudad segmento
# 0     Hombre       2011/11/24       SanMiguel      NaN
# 1        NaN         01-02-80        Sta. Ana      NaN
# 2  Masculino         06-18-79       S. Miguel      NaN
# 3  Masculino       1960-09-29      LaLibertad  REGULAR
# 4        NaN       1945/08/02   San Salvador      Pyme

# %%
print("Dimensiones del dataset (filas, columnas)")
print(df.shape)
# Out:
# Dimensiones del dataset (filas, columnas)
# (3030, 7)

# %%
print ("Columnas del dataset")
print (df.columns)
# Out:
# Columnas del dataset
# Index(['id_cliente', 'nombre', 'email', 'genero', 'fecha_nacimiento', 'ciudad',
#        'segmento'],
#       dtype='object')

# %%
print ("Tipos de datos")
print (df.dtypes)
# Out:
# Tipos de datos
# id_cliente           int64
# nombre              object
# email               object
# genero              object
# fecha_nacimiento    object
# ciudad              object
# segmento            object
# dtype: object

# %%
print("Valores nulos por columna")
print(df.isnull().sum())
# Out:
# Valores nulos por columna
# id_cliente            0
# nombre                0
# email                 0
# genero              595
# fecha_nacimiento      0
# ciudad                0
# segmento            597
# dtype: int64

# %%
print ("Registros duplicados")
print (df.duplicated().sum())
# Out:
# Registros duplicados
# 0

# %% [markdown]
# BLOQUE 3: Limpieza de datos

# %%
#Elimina espacios al inicio y al final en columnas de texto
for col in df.select_dtypes(include="object").columns:df[col]=df[col].str.strip()

# %%
#Normalizar nombre
df["nombre"]=df["nombre"].str.title()

# %%
#Normalizar email
df["email"]=df["email"].str.lower()

# %%
#Normalizar gennero
df["genero"]=df["genero"].str.upper()

# %%
#Convertir fecha de nacimiento a formato fecha
df["fecha_nacimiento"]=df["fecha_nacimiento"]=pd.to_datetime(df['fecha_nacimiento'],errors="coerce")

# %%
#Normalizar ciudad
df["ciudad"]=df['ciudad'].str.title()

# %%
#Limpieza de segmento
df['segmento']=df['segmento'].astype(str)
df['segmento']=df['segmento'].str.strip()
df['segmento']=df['segmento'].str.upper()

# %%
for col in df.columns: print (col)
# Out:
# id_cliente
# nombre
# email
# genero
# fecha_nacimiento
# ciudad
# segmento

# %% [markdown]
# BLOQUE 4: Validación de datos

# %%
#Crear columna para registrar errores
df["motivo_rechazo"]=""
#Validar id_cliente
df.loc[df["id_cliente"].isnull(),"motivo rechazo"] ="id_cliente nulo"
